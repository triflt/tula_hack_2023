# %%
#pip install openpyxl
#pip install shapely

# %%
import shapely.wkt

temp = shape_kladr['shape'].apply(lambda x: shapely.wkt.loads(x))

# %%
temp[442]
# Out:
# C:\Users\Даня\AppData\Local\Temp\ipykernel_36712\808014782.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   temp[442]
# <MULTIPOLYGON (((4289164.627 7162386.226, 4289193.477 7162392.882, 4289200.1...>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('../data/snapshoots/kimovsk2022-25-13.tif', cv2.IMREAD_UNCHANGED)
plt.imshow(img)

print(f'dtype: {img.dtype}, shape: {img.shape}, min: {np.min(img)}, max: {np.max(img)}')
# Out:
# dtype: uint8, shape: (5000, 5000, 4), min: 0, max: 255

# %% [markdown]
# ## CSV files

# %%
import pandas as pd

shape_kladr = pd.read_csv('../data/shape_kladr.csv', index_col=0)
shape_kladr.head(5)
# Out:
#          cadastral_                                              shape
# 0   71:11:010201:23  MULTIPOLYGON (((4290817.99858965 7167060.54559...
# 1   71:28:000000:19  MULTIPOLYGON (((4289407.25554663 7164797.04303...
# 2  71:28:000000:235  MULTIPOLYGON (((4289230.64218604 7163654.92466...
# 3  71:28:000000:236  MULTIPOLYGON (((4289488.35369173 7163481.57303...
# 4  71:28:000000:238  MULTIPOLYGON (((4291143.5328695 7162095.962553...

# %%
zu_data = pd.read_excel('../data/ЗУ_ИЖС+ЛПХ_без_ОКС_geo_Кимовск.xlsx', sheet_name=0, index_col=0)
zu_data.head(5)
# Out:
#                                                Категория  \
# 71:11:010208:267                Земли населенных пунктов
# 71:11:010103:322                Земли населенных пунктов
# 71:11:010501:208  Земли сельскохозяйственного назначения
# 71:11:040304:32                 Земли населенных пунктов
# 71:11:050206:85                 Земли населенных пунктов
#
#                                                                 ВРИ  \
# 71:11:010208:267  Для ведения личного подсобного хозяйствадля ве...
# 71:11:010103:322  Для ведения личного подсобного хозяйстваДля ве...
# 71:11:010501:208  Для ведения личного подсобного хозяйстваДля ве...
# 71:11:040304:32   Для ведения личного подсобного хозяйстваДля ве...
# 71:11:050206:85   Для ведения личного подсобного хозяйстваДля ве...
#
#                                           ВРИ по документу  \
# 71:11:010208:267  для ведения личного подсобного хозяйства
# 71:11:010103:322  Для ведения личного подсобного хозяйства
# ...

# %%
shape_kladr['cadastral_'].str.split(':')
# Out:
# 0        [71, 11, 010201, 23]
# 1        [71, 28, 000000, 19]
# 2       [71, 28, 000000, 235]
# 3       [71, 28, 000000, 236]
# 4       [71, 28, 000000, 238]
#                 ...
# 4517     [71, 28, 010606, 67]
# 4518     [71, 28, 010606, 69]
# 4519      [71, 28, 010606, 7]
# 4520     [71, 28, 010606, 70]
# 4521     [71, 28, 010606, 81]
# Name: cadastral_, Length: 4522, dtype: object
